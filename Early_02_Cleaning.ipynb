# %%
import pandas as pd

# %%
df = pd.concat([
    pd.read_csv('Output\Early_Data_Scraped-Raw.csv'),
    pd.read_csv('Output\Early_Data_Scraped-Raw_Backup_01.csv'),
    pd.read_csv('Output\Early_Data_Scraped-Raw_Backup_02.csv')
    ])
df = df.dropna()
df = df.drop_duplicates(subset=('title','price','land','building','location'), keep='last')
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                   title             price  \
# 0     RUMAH 2 LANTAI MURAH DLM RINGROAD, AREA FAVORI...  Rp 2.000.000.000
# 1             Rumah mewah dalam perum onegate di Jombor  Rp 2.200.000.000
# 2          Rumah baru di Jongke dalam cluster perumahan  Rp 1.890.000.000
# 3     Kode : RSH 3219 #Rumah Bagus Murah Strategis d...    Rp 600.000.000
# 4         Promo Rumah baru siap huni dalam perum sleman    Rp 395.000.000
# ...                                                 ...               ...
# 2868                  Jual cepat Rumah dan Gudang murah  Rp 5.300.000.000
# 2869  Rumah Dalam Kota Barat XT Square Dekat Jalan M...  Rp 1.500.000.000
# 2870    Rumah Baru di Area Kampus UNS (Cluster 26 Unit)    Rp 485.000.000
# 2871  Rumah cluster minimalis modern lingkungan kamp...    Rp 499.000.000
# 2872  Termurah 400Jt-an: Rumah Full Furnish 15Menit ...    Rp 475.000.000
#
#        land  building bed bath  floor                 certificate  \
# 0     130.0     130.0   5    5    2.0  SHM - Sertifikat Hak Milik
# 1     130.0     130.0   5    5    2.0  SHM - Sertifikat Hak Milik
# 2     130.0     130.0   5    5    2.0  SHM - Sertifikat Hak Milik
# 3     130.0      90.0   3    2    1.0  SHM - Sertifikat Hak Milik
# 4     110.0      50.0   3    1    0.0  SHM - Sertifikat Hak Milik
# ...     ...       ...  ..  ...    ...                         ...
# 2868  677.0     900.0   5    5    3.0  SHM - Sertifikat Hak Milik
# 2869   72.0     130.0   3    2    3.0  SHM - Sertifikat Hak Milik
# 2870   83.0      45.0   2    1    1.0  SHM - Sertifikat Hak Milik
# 2871   85.0      45.0   2    1    1.0  SHM - Sertifikat Hak Milik
# 2872  105.0      50.0   2    1    1.0  SHM - Sertifikat Hak Milik
#
#                                             location
# 0               Sleman, Sleman Kab., Yogyakarta D.I.
# 1               Sleman, Sleman Kab., Yogyakarta D.I.
# 2               Sleman, Sleman Kab., Yogyakarta D.I.
# 3               Sleman, Sleman Kab., Yogyakarta D.I.
# 4              Seyegan, Sleman Kab., Yogyakarta D.I.
# ...                                              ...
# 2868  Gondokusuman, Yogyakarta Kota, Yogyakarta D.I.
# 2869    Umbulharjo, Yogyakarta Kota, Yogyakarta D.I.
# 2870             Jebres, Surakarta Kota, Jawa Tengah
# 2871             Grogol, Sukoharjo Kab., Jawa Tengah
# 2872           Kasihan, Bantul Kab., Yogyakarta D.I.
#
# [2873 rows x 9 columns]

# %%
df.dtypes.info
# Out:
# <bound method Series.info of title           object
# price           object
# land           float64
# building       float64
# bed             object
# bath            object
# floor          float64
# certificate     object
# location        object
# dtype: object>

# %%
df = df.astype(str)

# %%
cols = ["price","land", "building", "bed", "bath", "floor", "certificate"]
for col in cols :
    df = df[df[f"{col}"].str.contains("&gt;10") == False]

# %%
df = df[df['location'].str.contains("Yogyakarta") == True]

# %%
conv = {
    'land': float, 
    'building': float,
    'bed': float,
    'bath':float,
    'floor': float
    }

df = df.astype(conv)

# %%
conv = {
    'land': int, 
    'building': int,
    'bed': int,
    'bath':int,
    'floor': int
    }

df = df.astype(conv)

# %%
df = df[(df['land']>0) == True]

# %%
df
# Out:
#                                                   title             price  \
# 0     RUMAH 2 LANTAI MURAH DLM RINGROAD, AREA FAVORI...  Rp 2.000.000.000
# 1             Rumah mewah dalam perum onegate di Jombor  Rp 2.200.000.000
# 2          Rumah baru di Jongke dalam cluster perumahan  Rp 1.890.000.000
# 3     Kode : RSH 3219 #Rumah Bagus Murah Strategis d...    Rp 600.000.000
# 4         Promo Rumah baru siap huni dalam perum sleman    Rp 395.000.000
# ...                                                 ...               ...
# 2866    Rumah minimalis siap huni di dkt pasar cebongan    Rp 625.000.000
# 2867  rumah cantik &amp; kos2an dekat univ aisyiah j...  Rp 1.300.000.000
# 2868                  Jual cepat Rumah dan Gudang murah  Rp 5.300.000.000
# 2869  Rumah Dalam Kota Barat XT Square Dekat Jalan M...  Rp 1.500.000.000
# 2872  Termurah 400Jt-an: Rumah Full Furnish 15Menit ...    Rp 475.000.000
#
#       land  building  bed  bath  floor                 certificate  \
# 0      130       130    5     5      2  SHM - Sertifikat Hak Milik
# 1      130       130    5     5      2  SHM - Sertifikat Hak Milik
# 2      130       130    5     5      2  SHM - Sertifikat Hak Milik
# 3      130        90    3     2      1  SHM - Sertifikat Hak Milik
# 4      110        50    3     1      0  SHM - Sertifikat Hak Milik
# ...    ...       ...  ...   ...    ...                         ...
# 2866   108        60    2     1      1  SHM - Sertifikat Hak Milik
# 2867    77       150    3     2      2  SHM - Sertifikat Hak Milik
# 2868   677       900    5     5      3  SHM - Sertifikat Hak Milik
# 2869    72       130    3     2      3  SHM - Sertifikat Hak Milik
# 2872   105        50    2     1      1  SHM - Sertifikat Hak Milik
#
#                                             location
# 0               Sleman, Sleman Kab., Yogyakarta D.I.
# 1               Sleman, Sleman Kab., Yogyakarta D.I.
# 2               Sleman, Sleman Kab., Yogyakarta D.I.
# 3               Sleman, Sleman Kab., Yogyakarta D.I.
# 4              Seyegan, Sleman Kab., Yogyakarta D.I.
# ...                                              ...
# 2866             Mlati, Sleman Kab., Yogyakarta D.I.
# 2867            Sleman, Sleman Kab., Yogyakarta D.I.
# 2868  Gondokusuman, Yogyakarta Kota, Yogyakarta D.I.
# 2869    Umbulharjo, Yogyakarta Kota, Yogyakarta D.I.
# 2872           Kasihan, Bantul Kab., Yogyakarta D.I.
#
# [2784 rows x 9 columns]

# %%
df.price = df.price.str.replace(r'\D+', '', regex=True)
df.price = df.price.astype('float')
df.price = df.price.astype('int64')

# %%
df.reset_index(inplace=True, drop=True)

# %%
df
# Out:
#                                                   title       price  land  \
# 0     RUMAH 2 LANTAI MURAH DLM RINGROAD, AREA FAVORI...  2000000000   130
# 1             Rumah mewah dalam perum onegate di Jombor  2200000000   130
# 2          Rumah baru di Jongke dalam cluster perumahan  1890000000   130
# 3     Kode : RSH 3219 #Rumah Bagus Murah Strategis d...   600000000   130
# 4         Promo Rumah baru siap huni dalam perum sleman   395000000   110
# ...                                                 ...         ...   ...
# 2779    Rumah minimalis siap huni di dkt pasar cebongan   625000000   108
# 2780  rumah cantik &amp; kos2an dekat univ aisyiah j...  1300000000    77
# 2781                  Jual cepat Rumah dan Gudang murah  5300000000   677
# 2782  Rumah Dalam Kota Barat XT Square Dekat Jalan M...  1500000000    72
# 2783  Termurah 400Jt-an: Rumah Full Furnish 15Menit ...   475000000   105
#
#       building  bed  bath  floor                 certificate  \
# 0          130    5     5      2  SHM - Sertifikat Hak Milik
# 1          130    5     5      2  SHM - Sertifikat Hak Milik
# 2          130    5     5      2  SHM - Sertifikat Hak Milik
# 3           90    3     2      1  SHM - Sertifikat Hak Milik
# 4           50    3     1      0  SHM - Sertifikat Hak Milik
# ...        ...  ...   ...    ...                         ...
# 2779        60    2     1      1  SHM - Sertifikat Hak Milik
# 2780       150    3     2      2  SHM - Sertifikat Hak Milik
# 2781       900    5     5      3  SHM - Sertifikat Hak Milik
# 2782       130    3     2      3  SHM - Sertifikat Hak Milik
# 2783        50    2     1      1  SHM - Sertifikat Hak Milik
#
#                                             location
# 0               Sleman, Sleman Kab., Yogyakarta D.I.
# 1               Sleman, Sleman Kab., Yogyakarta D.I.
# 2               Sleman, Sleman Kab., Yogyakarta D.I.
# 3               Sleman, Sleman Kab., Yogyakarta D.I.
# 4              Seyegan, Sleman Kab., Yogyakarta D.I.
# ...                                              ...
# 2779             Mlati, Sleman Kab., Yogyakarta D.I.
# 2780            Sleman, Sleman Kab., Yogyakarta D.I.
# 2781  Gondokusuman, Yogyakarta Kota, Yogyakarta D.I.
# 2782    Umbulharjo, Yogyakarta Kota, Yogyakarta D.I.
# 2783           Kasihan, Bantul Kab., Yogyakarta D.I.
#
# [2784 rows x 9 columns]

# %%
df.to_csv('Output\Mid_01_Data_Cleaned.csv', index=False)
